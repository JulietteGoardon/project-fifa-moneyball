# %%
import pandas as pd
import numpy as np

# %%
Fifa = pd.read_csv("Fifa 23 Players Data.csv")
Fifa
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  LM Rating  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
# ...                                                 ...  ...  ...        ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...         50
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...         45
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...         52
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...         33
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...         44
#
#        CM Rating  RM Rating  LWB Rating CDM Rating  RWB Rating  LB Rating  \
# 0             88         91          67         66          67         62
# 1             84         89          67         67          67         63
# 2             83         86          67         69          67         64
# 3             91         91          82         82          82         78
# 4             84         92          70         66          70         66
# ...          ...        ...         ...        ...         ...        ...
# 18534         44         50          41         38          41         40
# 18535         45         45          47         48          47         49
# 18536         49         52          46         44          46         46
# 18537         33         33          44         42          44         47
# 18538         40         44          46         43          46         47
#
#       CB Rating RB Rating GK Rating
# 0            53        62        22
# 1            58        63        21
# 2            63        64        22
# 3            72        78        24
# 4            57        66        21
# ...         ...       ...       ...
# 18534        36        40        15
# 18535        49        49        15
# 18536        42        46        17
# 18537        49        47        15
# 18538        47        47        19
#
# [18539 rows x 89 columns]

# %%
Fifa.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'Standing Tackle', 'Sliding Tackle',
#        'Goalkeeper Diving', 'Goalkeeper Handling', ' GoalkeeperKicking',
#        'Goalkeeper Positioning', 'Goalkeeper Reflexes', 'ST Rating',
#        'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
#        'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
#        'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
#        'GK Rating'],
#       dtype='object')

# %%
# Cleaning the data by selecting the columns we will use for our analysis.

Fifa_Cle = Fifa[['Known As', 'Overall', 'Potential', 'Value(in Euro)',
       'Positions Played', 'Best Position', 'Age',
       'Height(in cm)', 'Weight(in kg)',
       'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
       'Contract Until', 'Joined On', 'On Loan', 'National Team Name','ST Rating',
       'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
       'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
       'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
       'GK Rating','Nationality']]

# %%
# Add a column to understand the potential gap of each player.

Fifa_Cle["Gap_Potential"] = Fifa_Cle["Potential"] - Fifa_Cle["Overall"]
Fifa_Cle
# Out:
# <ipython-input-155-edf5cbb24997>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_Cle["Gap_Potential"] = Fifa_Cle["Potential"] - Fifa_Cle["Overall"]
#              Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 0            L. Messi       91         91        54000000               RW
# 1          K. Benzema       91         91        64000000            CF,ST
# 2      R. Lewandowski       91         91        84000000               ST
# 3        K. De Bruyne       91         91       107500000           CM,CAM
# 4           K. Mbappé       91         95       190500000            ST,LW
# ...               ...      ...        ...             ...              ...
# 18534      D. Collins       47         56          110000            ST,RM
# 18535    Yang Dejiang       47         57           90000              CDM
# 18536       L. Mullan       47         67          130000               CM
# 18537    D. McCallion       47         61          100000               CB
# 18538        N. Rabha       47         50           60000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)            Club Name  \
# 0               CAM   35            169             67  Paris Saint-Germain
# 1                CF   34            185             81       Real Madrid CF
# 2                ST   33            185             81         FC Barcelona
# 3                CM   31            181             70      Manchester City
# 4                ST   23            182             73  Paris Saint-Germain
# ...             ...  ...            ...            ...                  ...
# 18534           CAM   21            174             68         Sligo Rovers
# 18535           CDM   17            175             60         Guangzhou FC
# 18536            RM   18            170             65           Derry City
# 18537            CB   17            178             65           Derry City
# 18538            LB   25            176             66  NorthEast United FC
#
#        ...  RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 0      ...         91          67         66         67         62        53
# 1      ...         89          67         67         67         63        58
# 2      ...         86          67         69         67         64        63
# 3      ...         91          82         82         82         78        72
# 4      ...         92          70         66         70         66        57
# ...    ...        ...         ...        ...        ...        ...       ...
# 18534  ...         50          41         38         41         40        36
# 18535  ...         45          47         48         47         49        49
# 18536  ...         52          46         44         46         46        42
# 18537  ...         33          44         42         44         47        49
# 18538  ...         44          46         43         46         47        47
#
#       RB Rating  GK Rating          Nationality  Gap_Potential
# 0            62         22            Argentina              0
# 1            63         21               France              0
# 2            64         22               Poland              0
# 3            78         24              Belgium              0
# 4            66         21               France              4
# ...         ...        ...                  ...            ...
# 18534        40         15  Republic of Ireland              9
# 18535        49         15             China PR             10
# 18536        46         17     Northern Ireland             20
# 18537        47         15  Republic of Ireland             14
# 18538        47         19                India              3
#
# [18539 rows x 36 columns]

# %%
#Get the data of all the players at Manchester City to have an overview of the players scores and potentials.

Fifa_MC = Fifa_Cle.loc[Fifa_Cle['Club Name'] == "Manchester City"]
Fifa_MC
# Out:
#                 Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 3           K. De Bruyne       91         91       107500000           CM,CAM
# 16               Ederson       89         91        88000000               GK
# 20            Rúben Dias       88         91       107500000               CB
# 21            E. Haaland       88         94       148000000               ST
# 23        Bernardo Silva       88         88        97500000           CAM,CM
# 24          João Cancelo       88         88        82500000            LB,RB
# 31                 Rodri       87         89        88500000              CDM
# 48             R. Mahrez       86         86        56500000            RW,RM
# 55            A. Laporte       86         87        64500000               CB
# 68           İ. Gündoğan       85         85        44000000           CM,CDM
# 69             K. Walker       85         85        37500000               RB
# 83              P. Foden       85         92       109500000        LW,CF,CAM
# 103          J. Grealish       84         84        46000000        LW,LM,CAM
# 194            J. Stones       83         84        34500000               CB
# 320            M. Akanji       81         82        26500000               CB
# 361          K. Phillips       81         85        32000000           CDM,CM
# 430            S. Ortega       80         80        14500000               GK
# 680           J. Álvarez       78         86        32000000         ST,RW,LW
# 759               N. Aké       78         80        15000000            CB,LB
# 1972        Sergio Gómez       74         83         9000000         LB,RM,LM
# 8072           C. Palmer       67         85         2700000        RW,CAM,CF
# 9267           M. Rogers       66         82         2200000            LW,RW
# 10444          S. Carson       65         65           80000               GK
# 14529           R. Lewis       61         82         1000000               RB
# 15117          B. Knight       60         74          600000               RW
# 16308       A. Robertson       58         78          575000               CM
# 16314  J. Wilson-Esbrand       58         76          500000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)        Club Name  ...  \
# 3                CM   31            181             70  Manchester City  ...
# 16               GK   28            188             86  Manchester City  ...
# 20               CB   25            187             82  Manchester City  ...
# 21               ST   21            195             94  Manchester City  ...
# 23              CAM   27            173             64  Manchester City  ...
# 24               LB   28            182             74  Manchester City  ...
# 31              CDM   26            191             82  Manchester City  ...
# 48               RW   31            179             67  Manchester City  ...
# 55               CB   28            191             85  Manchester City  ...
# 68               CM   31            180             80  Manchester City  ...
# 69               RB   32            183             83  Manchester City  ...
# 83              CAM   22            171             69  Manchester City  ...
# 103              LW   26            180             81  Manchester City  ...
# 194              CB   28            188             76  Manchester City  ...
# 320              CB   26            187             91  Manchester City  ...
# 361             CDM   26            178             72  Manchester City  ...
# 430              GK   29            185             88  Manchester City  ...
# 680             CAM   22            173             71  Manchester City  ...
# 759              CB   27            180             75  Manchester City  ...
# 1972            CAM   21            171             68  Manchester City  ...
# 8072            CAM   20            189             74  Manchester City  ...
# 9267             RM   19            187             80  Manchester City  ...
# 10444            GK   36            190             86  Manchester City  ...
# 14529            RB   17            175             70  Manchester City  ...
# 15117           CAM   20            170             59  Manchester City  ...
# 16308           CAM   19            180             66  Manchester City  ...
# 16314            LB   19            176             65  Manchester City  ...
#
#        RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 3             91          82         82         82         78        72
# 16            47          40         47         40         39        38
# 20            67          81         86         81         83        90
# 21            80          65         67         65         64        65
# 23            88          79         77         79         75        67
# 24            88          88         86         88         87        82
# 31            79          82         87         82         82        85
# 48            86          67         64         67         62        52
# 55            70          80         85         80         81        87
# 68            85          80         83         80         78        75
# 69            81          85         84         85         85        84
# 83            87          75         74         75         72        62
# 103           84          71         70         71         66        57
# 194           73          80         83         80         81        84
# 320           70          78         82         78         80        82
# 361           76          80         82         80         79        81
# 430           39          35         40         35         34        35
# 680           81          69         69         69         67        64
# 759           71          78         79         78         79        80
# 1972          75          75         74         75         74        69
# 8072          68          59         57         59         57        52
# 9267          67          57         54         57         55        50
# 10444         27          26         27         26         26        29
# 14529         55          60         54         60         61        59
# 15117         60          47         43         47         44        38
# 16308         61          57         58         57         57        55
# 16314         56          58         53         58         58        56
#
#       RB Rating  GK Rating  Nationality  Gap_Potential
# 3            78         24      Belgium              0
# 16           39         90       Brazil              2
# 20           83         21     Portugal              3
# 21           64         22       Norway              6
# 23           75         21     Portugal              0
# 24           87         22     Portugal              0
# 31           82         21        Spain              2
# 48           62         21      Algeria              0
# 55           81         21        Spain              1
# 68           78         22      Germany              0
# 69           85         22      England              0
# 83           72         22      England              7
# 103          66         21      England              0
# 194          81         20      England              1
# 320          80         19  Switzerland              1
# 361          79         20      England              4
# 430          34         80      Germany              0
# 680          67         19    Argentina              8
# 759          79         21  Netherlands              2
# 1972         74         19        Spain              9
# 8072         57         17      England             18
# 9267         55         18      England             16
# 10444        26         65      England              0
# 14529        61         19      England             21
# 15117        44         16      England             14
# 16308        57         16      England             20
# 16314        58         16      England             18
#
# [27 rows x 36 columns]

# %%
# Get the data of all the players outside of Manchester City.

Fifa_Other = Fifa_Cle.loc[Fifa_Cle['Club Name'] != "Manchester City"]
Fifa_Other
# Out:
#              Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 0            L. Messi       91         91        54000000               RW
# 1          K. Benzema       91         91        64000000            CF,ST
# 2      R. Lewandowski       91         91        84000000               ST
# 4           K. Mbappé       91         95       190500000            ST,LW
# 5            M. Salah       90         90       115500000               RW
# ...               ...      ...        ...             ...              ...
# 18534      D. Collins       47         56          110000            ST,RM
# 18535    Yang Dejiang       47         57           90000              CDM
# 18536       L. Mullan       47         67          130000               CM
# 18537    D. McCallion       47         61          100000               CB
# 18538        N. Rabha       47         50           60000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)            Club Name  \
# 0               CAM   35            169             67  Paris Saint-Germain
# 1                CF   34            185             81       Real Madrid CF
# 2                ST   33            185             81         FC Barcelona
# 4                ST   23            182             73  Paris Saint-Germain
# 5                RW   30            175             71            Liverpool
# ...             ...  ...            ...            ...                  ...
# 18534           CAM   21            174             68         Sligo Rovers
# 18535           CDM   17            175             60         Guangzhou FC
# 18536            RM   18            170             65           Derry City
# 18537            CB   17            178             65           Derry City
# 18538            LB   25            176             66  NorthEast United FC
#
#        ...  RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 0      ...         91          67         66         67         62        53
# 1      ...         89          67         67         67         63        58
# 2      ...         86          67         69         67         64        63
# 4      ...         92          70         66         70         66        57
# 5      ...         90          74         71         74         70        61
# ...    ...        ...         ...        ...        ...        ...       ...
# 18534  ...         50          41         38         41         40        36
# 18535  ...         45          47         48         47         49        49
# 18536  ...         52          46         44         46         46        42
# 18537  ...         33          44         42         44         47        49
# 18538  ...         44          46         43         46         47        47
#
#       RB Rating  GK Rating          Nationality  Gap_Potential
# 0            62         22            Argentina              0
# 1            63         21               France              0
# 2            64         22               Poland              0
# 4            66         21               France              4
# 5            70         25                Egypt              0
# ...         ...        ...                  ...            ...
# 18534        40         15  Republic of Ireland              9
# 18535        49         15             China PR             10
# 18536        46         17     Northern Ireland             20
# 18537        47         15  Republic of Ireland             14
# 18538        47         19                India              3
#
# [18512 rows x 36 columns]

# %% [markdown]
# ***ANALYSIS 1 - Determining players to transfer according to their overall and potential. ***

# %%
# Create a new DataFrame to focus on the ratings of all the players (in and out of MC)

Fifa_Other.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'Club Name', 'Wage(in Euro)', 'Release Clause',
#        'Club Position', 'Contract Until', 'Joined On', 'On Loan',
#        'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
#        'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
#        'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
#        'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
#        'Gap_Potential'],
#       dtype='object')

# %%
Fifa_MP = Fifa_Cle[['Known As', 'Overall', 'Potential','Positions Played','Club Name',
       'Club Position', 'ST Rating', 'LW Rating', 'LF Rating',
       'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
       'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
       'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
       'Gap_Potential']]

# %%
# Add the mean value of the "Overall" column for each positions.
#With this code, we could get all the means of each rating per position.
#Estimating that most likely the overall score was already calculated according to the other ratings, we decided to focus on that column.

Fifa_MP.groupby(['Positions Played']).mean()

#Fifa_MP["Overall_Mean"] = Fifa_MP.groupby(['Club Position']).agg({"Overall":"mean"})
#Fifa_MP
# Out:
# <ipython-input-160-8ade671d6361>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Fifa_MP.groupby(['Positions Played']).mean()
#                     Overall  Potential  ST Rating  LW Rating  LF Rating  \
# Positions Played
# CAM               62.849462  71.451613  60.602151  62.311828  61.768817
# CAM,CDM           61.285714  66.285714  60.142857  59.857143  60.285714
# CAM,CDM,CM        69.200000  70.800000  66.600000  67.400000  67.400000
# CAM,CF            69.193548  75.838710  66.064516  68.516129  67.870968
# CAM,CF,CM         71.555556  74.888889  70.111111  70.555556  70.666667
# ...                     ...        ...        ...        ...        ...
# ST,RW,CF          66.000000  72.500000  67.000000  66.500000  66.000000
# ST,RW,CM          68.000000  77.000000  70.000000  68.000000  68.000000
# ST,RW,LW          64.615385  70.730769  66.076923  64.230769  64.307692
# ST,RW,RM          67.555556  71.222222  68.555556  65.777778  66.333333
# ST,RWB            56.666667  60.666667  58.666667  58.000000  57.000000
#
#                   CF Rating  RF Rating  RW Rating  CAM Rating  LM Rating  \
# Positions Played
# CAM               61.768817  61.768817  62.311828   64.327957  63.913978
# CAM,CDM           60.285714  60.285714  59.857143   62.714286  62.142857
# CAM,CDM,CM        67.400000  67.400000  67.400000   69.600000  68.800000
# CAM,CF            67.870968  67.870968  68.516129   70.516129  70.290323
# CAM,CF,CM         70.666667  70.666667  70.555556   72.444444  72.333333
# ...                     ...        ...        ...         ...        ...
# ST,RW,CF          66.000000  66.000000  66.500000   66.500000  67.000000
# ST,RW,CM          68.000000  68.000000  68.000000   68.000000  69.000000
# ST,RW,LW          64.307692  64.307692  64.230769   64.730769  64.730769
# ST,RW,RM          66.333333  66.333333  65.777778   66.111111  66.222222
# ST,RWB            57.000000  57.000000  58.000000   57.333333  59.000000
#
#                   CM Rating  RM Rating  LWB Rating  CDM Rating  RWB Rating  \
# Positions Played
# CAM               61.204301  63.913978   53.924731   52.483871   53.924731
# CAM,CDM           62.571429  62.142857   60.857143   61.142857   60.857143
# CAM,CDM,CM        69.600000  68.800000   65.400000   66.600000   65.400000
# CAM,CF            67.516129  70.290323   58.903226   57.064516   58.903226
# CAM,CF,CM         71.333333  72.333333   67.111111   67.111111   67.111111
# ...                     ...        ...         ...         ...         ...
# ST,RW,CF          63.000000  67.000000   54.000000   49.500000   54.000000
# ST,RW,CM          61.000000  69.000000   53.000000   50.000000   53.000000
# ST,RW,LW          58.269231  64.730769   51.076923   48.307692   51.076923
# ST,RW,RM          59.222222  66.222222   50.444444   47.333333   50.444444
# ST,RWB            53.333333  59.000000   53.333333   49.666667   53.333333
#
#                   LB Rating  CB Rating  RB Rating  GK Rating  Gap_Potential
# Positions Played
# CAM               51.704301  46.532258  51.704301  17.505376       8.602151
# CAM,CDM           59.714286  58.857143  59.714286  18.285714       5.000000
# CAM,CDM,CM        63.800000  60.800000  63.800000  18.400000       1.600000
# CAM,CF            55.870968  49.258065  55.870968  18.741935       6.645161
# CAM,CF,CM         65.555556  62.222222  65.555556  19.000000       3.333333
# ...                     ...        ...        ...        ...            ...
# ST,RW,CF          50.000000  42.500000  50.000000  17.500000       6.500000
# ST,RW,CM          50.000000  44.000000  50.000000  19.000000       9.000000
# ST,RW,LW          49.076923  45.423077  49.076923  17.692308       6.115385
# ST,RW,RM          47.777778  44.444444  47.777778  18.222222       3.666667
# ST,RWB            53.000000  49.333333  53.000000  17.000000       4.000000
#
# [693 rows x 20 columns]

# %%
#Calculate the mean values for each position:
position_means = Fifa_MP.groupby(['Positions Played'])['Overall'].mean().reset_index()

#Rename the "Overall" column with the position_means DataFrame to "Mean Overall".
position_means.rename(columns={'Overall': 'Mean Overall'}, inplace=True)

#Merge the mean values back into your initial DataFrame based on the "Club Position" column:
Fifa_MP = Fifa_MP.merge(position_means, on='Positions Played', how='left')

Fifa_MP
# Out:
#              Known As  Overall  Potential Positions Played  \
# 0            L. Messi       91         91               RW
# 1          K. Benzema       91         91            CF,ST
# 2      R. Lewandowski       91         91               ST
# 3        K. De Bruyne       91         91           CM,CAM
# 4           K. Mbappé       91         95            ST,LW
# ...               ...      ...        ...              ...
# 18534      D. Collins       47         56            ST,RM
# 18535    Yang Dejiang       47         57              CDM
# 18536       L. Mullan       47         67               CM
# 18537    D. McCallion       47         61               CB
# 18538        N. Rabha       47         50               LB
#
#                  Club Name Club Position  ST Rating  LW Rating  LF Rating  \
# 0      Paris Saint-Germain            RW         90         90         91
# 1           Real Madrid CF            CF         91         87         89
# 2             FC Barcelona            ST         91         85         88
# 3          Manchester City            CM         86         88         87
# 4      Paris Saint-Germain            ST         92         90         90
# ...                    ...           ...        ...        ...        ...
# 18534         Sligo Rovers           RES         49         50         50
# 18535         Guangzhou FC           SUB         44         43         43
# 18536           Derry City           SUB         48         49         49
# 18537           Derry City           SUB         33         30         30
# 18538  NorthEast United FC           RES         41         42         40
#
#        CF Rating  ...  LWB Rating  CDM Rating  RWB Rating  LB Rating  \
# 0             91  ...          67          66          67         62
# 1             89  ...          67          67          67         63
# 2             88  ...          67          69          67         64
# 3             87  ...          82          82          82         78
# 4             90  ...          70          66          70         66
# ...          ...  ...         ...         ...         ...        ...
# 18534         50  ...          41          38          41         40
# 18535         43  ...          47          48          47         49
# 18536         49  ...          46          44          46         46
# 18537         30  ...          44          42          44         47
# 18538         40  ...          46          43          46         47
#
#        CB Rating  RB Rating  GK Rating          Nationality  Gap_Potential  \
# 0             53         62         22            Argentina              0
# 1             58         63         21               France              0
# 2             63         64         22               Poland              0
# 3             72         78         24              Belgium              0
# 4             57         66         21               France              4
# ...          ...        ...        ...                  ...            ...
# 18534         36         40         15  Republic of Ireland              9
# 18535         49         49         15             China PR             10
# 18536         42         46         17     Northern Ireland             20
# 18537         49         47         15  Republic of Ireland             14
# 18538         47         47         19                India              3
#
#        Mean Overall
# 0         65.040816
# 1         71.095238
# 2         65.657941
# 3         66.021186
# 4         65.962121
# ...             ...
# 18534     65.237500
# 18535     63.166023
# 18536     62.662568
# 18537     66.445540
# 18538     65.231660
#
# [18539 rows x 26 columns]

# %%
#Re-order the columns to have "Overall" next to "Mean Overall"

Fifa_MP.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Positions Played', 'Club Name',
#        'Club Position', 'ST Rating', 'LW Rating', 'LF Rating', 'CF Rating',
#        'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating', 'CM Rating',
#        'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating', 'LB Rating',
#        'CB Rating', 'RB Rating', 'GK Rating', 'Nationality', 'Gap_Potential',
#        'Mean Overall'],
#       dtype='object')

# %%
Fifa_MP = Fifa_MP[['Known As','Overall', 'Mean Overall','Potential','Positions Played','Club Position', 'Club Name', 'ST Rating',
       'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
       'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
       'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
       'GK Rating', 'Nationality', 'Gap_Potential']]

Fifa_MP
# Out:
#              Known As  Overall  Mean Overall  Potential Positions Played  \
# 0            L. Messi       91     65.040816         91               RW
# 1          K. Benzema       91     71.095238         91            CF,ST
# 2      R. Lewandowski       91     65.657941         91               ST
# 3        K. De Bruyne       91     66.021186         91           CM,CAM
# 4           K. Mbappé       91     65.962121         95            ST,LW
# ...               ...      ...           ...        ...              ...
# 18534      D. Collins       47     65.237500         56            ST,RM
# 18535    Yang Dejiang       47     63.166023         57              CDM
# 18536       L. Mullan       47     62.662568         67               CM
# 18537    D. McCallion       47     66.445540         61               CB
# 18538        N. Rabha       47     65.231660         50               LB
#
#       Club Position            Club Name  ST Rating  LW Rating  LF Rating  \
# 0                RW  Paris Saint-Germain         90         90         91
# 1                CF       Real Madrid CF         91         87         89
# 2                ST         FC Barcelona         91         85         88
# 3                CM      Manchester City         86         88         87
# 4                ST  Paris Saint-Germain         92         90         90
# ...             ...                  ...        ...        ...        ...
# 18534           RES         Sligo Rovers         49         50         50
# 18535           SUB         Guangzhou FC         44         43         43
# 18536           SUB           Derry City         48         49         49
# 18537           SUB           Derry City         33         30         30
# 18538           RES  NorthEast United FC         41         42         40
#
#        ...  RM Rating  LWB Rating  CDM Rating  RWB Rating  LB Rating  \
# 0      ...         91          67          66          67         62
# 1      ...         89          67          67          67         63
# 2      ...         86          67          69          67         64
# 3      ...         91          82          82          82         78
# 4      ...         92          70          66          70         66
# ...    ...        ...         ...         ...         ...        ...
# 18534  ...         50          41          38          41         40
# 18535  ...         45          47          48          47         49
# 18536  ...         52          46          44          46         46
# 18537  ...         33          44          42          44         47
# 18538  ...         44          46          43          46         47
#
#        CB Rating  RB Rating  GK Rating          Nationality  Gap_Potential
# 0             53         62         22            Argentina              0
# 1             58         63         21               France              0
# 2             63         64         22               Poland              0
# 3             72         78         24              Belgium              0
# 4             57         66         21               France              4
# ...          ...        ...        ...                  ...            ...
# 18534         36         40         15  Republic of Ireland              9
# 18535         49         49         15             China PR             10
# 18536         42         46         17     Northern Ireland             20
# 18537         49         47         15  Republic of Ireland             14
# 18538         47         47         19                India              3
#
# [18539 rows x 26 columns]

# %%
Fifa_MC = Fifa_MP.loc[Fifa_MP['Club Name'] == "Manchester City"]
Fifa_MC
# Out:
#                 Known As  Overall  Mean Overall  Potential Positions Played  \
# 3           K. De Bruyne       91     66.021186         91           CM,CAM
# 16               Ederson       89     64.453178         91               GK
# 20            Rúben Dias       88     66.445540         91               CB
# 21            E. Haaland       88     65.657941         94               ST
# 23        Bernardo Silva       88     66.387597         88           CAM,CM
# 24          João Cancelo       88     65.800000         88            LB,RB
# 31                 Rodri       87     63.166023         89              CDM
# 48             R. Mahrez       86     69.339623         86            RW,RM
# 55            A. Laporte       86     66.445540         87               CB
# 68           İ. Gündoğan       85     67.120235         85           CM,CDM
# 69             K. Walker       85     65.377871         85               RB
# 83              P. Foden       85     77.500000         92        LW,CF,CAM
# 103          J. Grealish       84     69.250000         84        LW,LM,CAM
# 194            J. Stones       83     66.445540         84               CB
# 320            M. Akanji       81     66.445540         82               CB
# 361          K. Phillips       81     67.414481         85           CDM,CM
# 430            S. Ortega       80     64.453178         80               GK
# 680           J. Álvarez       78     64.615385         86         ST,RW,LW
# 759               N. Aké       78     66.200000         80            CB,LB
# 1972        Sergio Gómez       74     69.500000         83         LB,RM,LM
# 8072           C. Palmer       67     67.000000         85        RW,CAM,CF
# 9267           M. Rogers       66     66.170000         82            LW,RW
# 10444          S. Carson       65     64.453178         65               GK
# 14529           R. Lewis       61     65.377871         82               RB
# 15117          B. Knight       60     65.040816         74               RW
# 16308       A. Robertson       58     62.662568         78               CM
# 16314  J. Wilson-Esbrand       58     65.231660         76               LB
#
#       Club Position        Club Name  ST Rating  LW Rating  LF Rating  ...  \
# 3                CM  Manchester City         86         88         87  ...
# 16               GK  Manchester City         43         41         43  ...
# 20               CB  Manchester City         64         59         60  ...
# 21               ST  Manchester City         90         80         84  ...
# 23               RW  Manchester City         80         86         84  ...
# 24               LB  Manchester City         81         84         83  ...
# 31              CDM  Manchester City         79         74         77  ...
# 48              SUB  Manchester City         83         85         85  ...
# 55               CB  Manchester City         69         64         66  ...
# 68               CM  Manchester City         81         82         82  ...
# 69               RB  Manchester City         77         76         76  ...
# 83               LW  Manchester City         80         84         83  ...
# 103             SUB  Manchester City         78         83         81  ...
# 194             SUB  Manchester City         69         69         69  ...
# 320             SUB  Manchester City         66         65         65  ...
# 361             SUB  Manchester City         72         72         72  ...
# 430             SUB  Manchester City         37         34         37  ...
# 680             SUB  Manchester City         80         80         80  ...
# 759             SUB  Manchester City         68         67         66  ...
# 1972            SUB  Manchester City         70         73         72  ...
# 8072            SUB  Manchester City         65         67         66  ...
# 9267            RES  Manchester City         66         66         65  ...
# 10444           SUB  Manchester City         30         25         27  ...
# 14529           SUB  Manchester City         50         53         50  ...
# 15117           RES  Manchester City         58         60         59  ...
# 16308           RES  Manchester City         58         57         58  ...
# 16314           RES  Manchester City         49         53         50  ...
#
#        RM Rating  LWB Rating  CDM Rating  RWB Rating  LB Rating  CB Rating  \
# 3             91          82          82          82         78         72
# 16            47          40          47          40         39         38
# 20            67          81          86          81         83         90
# 21            80          65          67          65         64         65
# 23            88          79          77          79         75         67
# 24            88          88          86          88         87         82
# 31            79          82          87          82         82         85
# 48            86          67          64          67         62         52
# 55            70          80          85          80         81         87
# 68            85          80          83          80         78         75
# 69            81          85          84          85         85         84
# 83            87          75          74          75         72         62
# 103           84          71          70          71         66         57
# 194           73          80          83          80         81         84
# 320           70          78          82          78         80         82
# 361           76          80          82          80         79         81
# 430           39          35          40          35         34         35
# 680           81          69          69          69         67         64
# 759           71          78          79          78         79         80
# 1972          75          75          74          75         74         69
# 8072          68          59          57          59         57         52
# 9267          67          57          54          57         55         50
# 10444         27          26          27          26         26         29
# 14529         55          60          54          60         61         59
# 15117         60          47          43          47         44         38
# 16308         61          57          58          57         57         55
# 16314         56          58          53          58         58         56
#
#        RB Rating  GK Rating  Nationality  Gap_Potential
# 3             78         24      Belgium              0
# 16            39         90       Brazil              2
# 20            83         21     Portugal              3
# 21            64         22       Norway              6
# 23            75         21     Portugal              0
# 24            87         22     Portugal              0
# 31            82         21        Spain              2
# 48            62         21      Algeria              0
# 55            81         21        Spain              1
# 68            78         22      Germany              0
# 69            85         22      England              0
# 83            72         22      England              7
# 103           66         21      England              0
# 194           81         20      England              1
# 320           80         19  Switzerland              1
# 361           79         20      England              4
# 430           34         80      Germany              0
# 680           67         19    Argentina              8
# 759           79         21  Netherlands              2
# 1972          74         19        Spain              9
# 8072          57         17      England             18
# 9267          55         18      England             16
# 10444         26         65      England              0
# 14529         61         19      England             21
# 15117         44         16      England             14
# 16308         57         16      England             20
# 16314         58         16      England             18
#
# [27 rows x 26 columns]

# %%
"""

This is where we realized that we only have substitutes and reserve club positions players with an overall score below the mean score of all the other players.
We took the decision to instead take the mean of the Top 10 champions league teams of 2023-2024 which are the following:

1. Manchester City
2. Real Madrid
3. FC Barcelona
4. Bayern Munich
5. Inter
6. Real Sociedad
7. Arsenal
8. PSG
9. Atletico de Madrid
10. Porto

"""
# Out:
# '\n\nThis is where we realized that we only have substitutes and reserve club positions players with an overall score below the mean score of all the other players. \nWe took the decision to instead take the mean of the Top 10 champions league teams of 2023-2024 which are the following: \n\n1. Manchester City\n2. Real Madrid\n3. FC Barcelona\n4. Bayern Munich\n5. Inter\n6. Real Sociedad \n7. Arsenal \n8. PSG\n9. Atletico de Madrid\n10. Porto \n\n'

# %%
#Creating a new DataFrame with the data of the top 10 teams in our Champions league ranking.

Fifa_Champions = Fifa_Cle[Fifa_Cle['Club Name'].isin(["Manchester City", "Real Madrid", "FC Barcelona","Bayern Munich","Inter","Real Sociedad", "Arsenal","Paris Saint-Germain", "Atletico de Madrid","Porto"])]

Fifa_Champions
# Out:
#                 Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 0               L. Messi       91         91        54000000               RW
# 2         R. Lewandowski       91         91        84000000               ST
# 3           K. De Bruyne       91         91       107500000           CM,CAM
# 4              K. Mbappé       91         95       190500000            ST,LW
# 11             Neymar Jr       89         89        99500000               LW
# ...                  ...      ...        ...             ...              ...
# 15117          B. Knight       60         74          600000               RW
# 15912  A. Cozier-Duberry       59         78          550000           LM,CAM
# 16308       A. Robertson       58         78          575000               CM
# 16314  J. Wilson-Esbrand       58         76          500000               LB
# 16986           L. Sousa       56         80          425000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)            Club Name  \
# 0               CAM   35            169             67  Paris Saint-Germain
# 2                ST   33            185             81         FC Barcelona
# 3                CM   31            181             70      Manchester City
# 4                ST   23            182             73  Paris Saint-Germain
# 11               LW   30            175             68  Paris Saint-Germain
# ...             ...  ...            ...            ...                  ...
# 15117           CAM   20            170             59      Manchester City
# 15912            LM   17            170             60              Arsenal
# 16308           CAM   19            180             66      Manchester City
# 16314            LB   19            176             65      Manchester City
# 16986            LB   17            185             70              Arsenal
#
#        ...  RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 0      ...         91          67         66         67         62        53
# 2      ...         86          67         69         67         64        63
# 3      ...         91          82         82         82         78        72
# 4      ...         92          70         66         70         66        57
# 11     ...         89          69         66         69         64        53
# ...    ...        ...         ...        ...        ...        ...       ...
# 15117  ...         60          47         43         47         44        38
# 15912  ...         60          48         44         48         45        39
# 16308  ...         61          57         58         57         57        55
# 16314  ...         56          58         53         58         58        56
# 16986  ...         52          56         52         56         56        56
#
#       RB Rating  GK Rating  Nationality  Gap_Potential
# 0            62         22    Argentina              0
# 2            64         22       Poland              0
# 3            78         24      Belgium              0
# 4            66         21       France              4
# 11           64         23       Brazil              0
# ...         ...        ...          ...            ...
# 15117        44         16      England             14
# 15912        45         17      England             19
# 16308        57         16      England             20
# 16314        58         16      England             18
# 16986        56         17      England             24
#
# [173 rows x 36 columns]

# %%
#Calculate the mean values for each position:
position_means2 = Fifa_Champions.groupby(['Positions Played'])['Overall'].mean().reset_index()

#Rename the "Overall" column with the position_means DataFrame to "Mean Overall".
position_means2.rename(columns={'Overall': 'Mean Overall'}, inplace=True)

#Merge the mean values back into your initial DataFrame based on the "Club Position" column:
Fifa_Champions = Fifa_Champions.merge(position_means2, on='Positions Played', how='left')

Fifa_Champions
# Out:
#               Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 0             L. Messi       91         91        54000000               RW
# 1       R. Lewandowski       91         91        84000000               ST
# 2         K. De Bruyne       91         91       107500000           CM,CAM
# 3            K. Mbappé       91         95       190500000            ST,LW
# 4            Neymar Jr       89         89        99500000               LW
# ..                 ...      ...        ...             ...              ...
# 168          B. Knight       60         74          600000               RW
# 169  A. Cozier-Duberry       59         78          550000           LM,CAM
# 170       A. Robertson       58         78          575000               CM
# 171  J. Wilson-Esbrand       58         76          500000               LB
# 172           L. Sousa       56         80          425000               LB
#
#     Best Position  Age  Height(in cm)  Weight(in kg)            Club Name  \
# 0             CAM   35            169             67  Paris Saint-Germain
# 1              ST   33            185             81         FC Barcelona
# 2              CM   31            181             70      Manchester City
# 3              ST   23            182             73  Paris Saint-Germain
# 4              LW   30            175             68  Paris Saint-Germain
# ..            ...  ...            ...            ...                  ...
# 168           CAM   20            170             59      Manchester City
# 169            LM   17            170             60              Arsenal
# 170           CAM   19            180             66      Manchester City
# 171            LB   19            176             65      Manchester City
# 172            LB   17            185             70              Arsenal
#
#      ...  LWB Rating  CDM Rating RWB Rating LB Rating  CB Rating RB Rating  \
# 0    ...          67          66         67        62         53        62
# 1    ...          67          69         67        64         63        64
# 2    ...          82          82         82        78         72        78
# 3    ...          70          66         70        66         57        66
# 4    ...          69          66         69        64         53        64
# ..   ...         ...         ...        ...       ...        ...       ...
# 168  ...          47          43         47        44         38        44
# 169  ...          48          44         48        45         39        45
# 170  ...          57          58         57        57         55        57
# 171  ...          58          53         58        58         56        58
# 172  ...          56          52         56        56         56        56
#
#     GK Rating  Nationality  Gap_Potential  Mean Overall
# 0          22    Argentina              0     70.000000
# 1          22       Poland              0     79.454545
# 2          24      Belgium              0     85.666667
# 3          21       France              4     77.000000
# 4          23       Brazil              0     80.666667
# ..        ...          ...            ...           ...
# 168        16      England             14     70.000000
# 169        17      England             19     69.500000
# 170        16      England             20     79.857143
# 171        16      England             18     73.400000
# 172        17      England             24     73.400000
#
# [173 rows x 37 columns]

# %%
Fifa_Champions.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'Club Name', 'Wage(in Euro)', 'Release Clause',
#        'Club Position', 'Contract Until', 'Joined On', 'On Loan',
#        'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
#        'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
#        'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
#        'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
#        'Gap_Potential', 'Mean Overall'],
#       dtype='object')

# %%
Fifa_Champions = Fifa_Champions[['Known As', 'Overall','Mean Overall', 'Potential','Positions Played','Club Name', 'Value(in Euro)', 'Best Position', 'Wage(in Euro)', 'Release Clause',
       'Club Position', 'Contract Until', 'Joined On', 'On Loan',
       'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
       'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
       'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
       'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
       'Gap_Potential']]

# %%
#Checking again the overall score of our players in Manchester City compared to the mean of the Champions League top teams.

Fifa_MC2 = Fifa_Champions.loc[Fifa_Champions['Club Name'] == "Manchester City"]
Fifa_MC2
# Out:
#               Known As  Overall  Mean Overall  Potential Positions Played  \
# 2         K. De Bruyne       91     85.666667         91           CM,CAM
# 5              Ederson       89     76.473684         91               GK
# 6           Rúben Dias       88     80.083333         91               CB
# 7           E. Haaland       88     79.454545         94               ST
# 9       Bernardo Silva       88     84.000000         88           CAM,CM
# 10        João Cancelo       88     88.000000         88            LB,RB
# 14               Rodri       87     79.000000         89              CDM
# 18           R. Mahrez       86     84.500000         86            RW,RM
# 19          A. Laporte       86     80.083333         87               CB
# 24         İ. Gündoğan       85     73.555556         85           CM,CDM
# 25           K. Walker       85     76.000000         85               RB
# 30            P. Foden       85     85.000000         92        LW,CF,CAM
# 35         J. Grealish       84     84.000000         84        LW,LM,CAM
# 54           J. Stones       83     80.083333         84               CB
# 66           M. Akanji       81     80.083333         82               CB
# 71         K. Phillips       81     79.777778         85           CDM,CM
# 77           S. Ortega       80     76.473684         80               GK
# 92          J. Álvarez       78     78.000000         86         ST,RW,LW
# 95              N. Aké       78     72.500000         80            CB,LB
# 118       Sergio Gómez       74     74.000000         83         LB,RM,LM
# 147          C. Palmer       67     67.000000         85        RW,CAM,CF
# 149          M. Rogers       66     71.333333         82            LW,RW
# 153          S. Carson       65     76.473684         65               GK
# 167           R. Lewis       61     76.000000         82               RB
# 168          B. Knight       60     70.000000         74               RW
# 170       A. Robertson       58     79.857143         78               CM
# 171  J. Wilson-Esbrand       58     73.400000         76               LB
#
#            Club Name  Value(in Euro) Best Position  Wage(in Euro)  \
# 2    Manchester City       107500000            CM         350000
# 5    Manchester City        88000000            GK         210000
# 6    Manchester City       107500000            CB         230000
# 7    Manchester City       148000000            ST         220000
# 9    Manchester City        97500000           CAM         260000
# 10   Manchester City        82500000            LB         250000
# 14   Manchester City        88500000           CDM         200000
# 18   Manchester City        56500000            RW         220000
# 19   Manchester City        64500000            CB         195000
# 24   Manchester City        44000000            CM         185000
# 25   Manchester City        37500000            RB         170000
# 30   Manchester City       109500000           CAM         180000
# 35   Manchester City        46000000            LW         185000
# 54   Manchester City        34500000            CB         150000
# 66   Manchester City        26500000            CB         120000
# 71   Manchester City        32000000           CDM         120000
# 77   Manchester City        14500000            GK          95000
# 92   Manchester City        32000000           CAM         100000
# 95   Manchester City        15000000            CB          95000
# 118  Manchester City         9000000           CAM          53000
# 147  Manchester City         2700000           CAM          26000
# 149  Manchester City         2200000            RM          17000
# 153  Manchester City           80000            GK          11000
# 167  Manchester City         1000000            RB            650
# 168  Manchester City          600000           CAM          12000
# 170  Manchester City          575000           CAM           8000
# 171  Manchester City          500000            LB           7000
#
#      Release Clause  ... RM Rating LWB Rating  CDM Rating RWB Rating  \
# 2         198900000  ...        91         82          82         82
# 5         169400000  ...        47         40          47         40
# 6         206900000  ...        67         81          86         81
# 7         303400000  ...        80         65          67         65
# 9         180400000  ...        88         79          77         79
# 10        152600000  ...        88         88          86         88
# 14        170400000  ...        79         82          87         82
# 18        104500000  ...        86         67          64         67
# 19        124200000  ...        70         80          85         80
# 24         81400000  ...        85         80          83         80
# 25         69400000  ...        81         85          84         85
# 30        224500000  ...        87         75          74         75
# 35         85100000  ...        84         71          70         71
# 54         66400000  ...        73         80          83         80
# 66         51000000  ...        70         78          82         78
# 71         61600000  ...        76         80          82         80
# 77         26800000  ...        39         35          40         35
# 92         65599999  ...        81         69          69         69
# 95         28900000  ...        71         78          79         78
# 118        18500000  ...        75         75          74         75
# 147         6700000  ...        68         59          57         59
# 149         5400000  ...        67         57          54         57
# 153          148000  ...        27         26          27         26
# 167         2900000  ...        55         60          54         60
# 168         1500000  ...        60         47          43         47
# 170         1600000  ...        61         57          58         57
# 171         1200000  ...        56         58          53         58
#
#     LB Rating  CB Rating  RB Rating  GK Rating  Nationality  Gap_Potential
# 2          78         72         78         24      Belgium              0
# 5          39         38         39         90       Brazil              2
# 6          83         90         83         21     Portugal              3
# 7          64         65         64         22       Norway              6
# 9          75         67         75         21     Portugal              0
# 10         87         82         87         22     Portugal              0
# 14         82         85         82         21        Spain              2
# 18         62         52         62         21      Algeria              0
# 19         81         87         81         21        Spain              1
# 24         78         75         78         22      Germany              0
# 25         85         84         85         22      England              0
# 30         72         62         72         22      England              7
# 35         66         57         66         21      England              0
# 54         81         84         81         20      England              1
# 66         80         82         80         19  Switzerland              1
# 71         79         81         79         20      England              4
# 77         34         35         34         80      Germany              0
# 92         67         64         67         19    Argentina              8
# 95         79         80         79         21  Netherlands              2
# 118        74         69         74         19        Spain              9
# 147        57         52         57         17      England             18
# 149        55         50         55         18      England             16
# 153        26         29         26         65      England              0
# 167        61         59         61         19      England             21
# 168        44         38         44         16      England             14
# 170        57         55         57         16      England             20
# 171        58         56         58         16      England             18
#
# [27 rows x 34 columns]

# %%
#As we also wanted to take into account the potential, we created a new column taking it inot account.

Fifa_MC2["Real_OScore"] = (Fifa_MC2["Overall"] + Fifa_MC2["Potential"])/ 2

Fifa_MC2
# Out:
# <ipython-input-171-912bf388f369>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_MC2["Real_OScore"] = (Fifa_MC2["Overall"] + Fifa_MC2["Potential"])/ 2
#               Known As  Overall  Mean Overall  Potential Positions Played  \
# 2         K. De Bruyne       91     85.666667         91           CM,CAM
# 5              Ederson       89     76.473684         91               GK
# 6           Rúben Dias       88     80.083333         91               CB
# 7           E. Haaland       88     79.454545         94               ST
# 9       Bernardo Silva       88     84.000000         88           CAM,CM
# 10        João Cancelo       88     88.000000         88            LB,RB
# 14               Rodri       87     79.000000         89              CDM
# 18           R. Mahrez       86     84.500000         86            RW,RM
# 19          A. Laporte       86     80.083333         87               CB
# 24         İ. Gündoğan       85     73.555556         85           CM,CDM
# 25           K. Walker       85     76.000000         85               RB
# 30            P. Foden       85     85.000000         92        LW,CF,CAM
# 35         J. Grealish       84     84.000000         84        LW,LM,CAM
# 54           J. Stones       83     80.083333         84               CB
# 66           M. Akanji       81     80.083333         82               CB
# 71         K. Phillips       81     79.777778         85           CDM,CM
# 77           S. Ortega       80     76.473684         80               GK
# 92          J. Álvarez       78     78.000000         86         ST,RW,LW
# 95              N. Aké       78     72.500000         80            CB,LB
# 118       Sergio Gómez       74     74.000000         83         LB,RM,LM
# 147          C. Palmer       67     67.000000         85        RW,CAM,CF
# 149          M. Rogers       66     71.333333         82            LW,RW
# 153          S. Carson       65     76.473684         65               GK
# 167           R. Lewis       61     76.000000         82               RB
# 168          B. Knight       60     70.000000         74               RW
# 170       A. Robertson       58     79.857143         78               CM
# 171  J. Wilson-Esbrand       58     73.400000         76               LB
#
#            Club Name  Value(in Euro) Best Position  Wage(in Euro)  \
# 2    Manchester City       107500000            CM         350000
# 5    Manchester City        88000000            GK         210000
# 6    Manchester City       107500000            CB         230000
# 7    Manchester City       148000000            ST         220000
# 9    Manchester City        97500000           CAM         260000
# 10   Manchester City        82500000            LB         250000
# 14   Manchester City        88500000           CDM         200000
# 18   Manchester City        56500000            RW         220000
# 19   Manchester City        64500000            CB         195000
# 24   Manchester City        44000000            CM         185000
# 25   Manchester City        37500000            RB         170000
# 30   Manchester City       109500000           CAM         180000
# 35   Manchester City        46000000            LW         185000
# 54   Manchester City        34500000            CB         150000
# 66   Manchester City        26500000            CB         120000
# 71   Manchester City        32000000           CDM         120000
# 77   Manchester City        14500000            GK          95000
# 92   Manchester City        32000000           CAM         100000
# 95   Manchester City        15000000            CB          95000
# 118  Manchester City         9000000           CAM          53000
# 147  Manchester City         2700000           CAM          26000
# 149  Manchester City         2200000            RM          17000
# 153  Manchester City           80000            GK          11000
# 167  Manchester City         1000000            RB            650
# 168  Manchester City          600000           CAM          12000
# 170  Manchester City          575000           CAM           8000
# 171  Manchester City          500000            LB           7000
#
#      Release Clause  ... LWB Rating CDM Rating  RWB Rating LB Rating  \
# 2         198900000  ...         82         82          82        78
# 5         169400000  ...         40         47          40        39
# 6         206900000  ...         81         86          81        83
# 7         303400000  ...         65         67          65        64
# 9         180400000  ...         79         77          79        75
# 10        152600000  ...         88         86          88        87
# 14        170400000  ...         82         87          82        82
# 18        104500000  ...         67         64          67        62
# 19        124200000  ...         80         85          80        81
# 24         81400000  ...         80         83          80        78
# 25         69400000  ...         85         84          85        85
# 30        224500000  ...         75         74          75        72
# 35         85100000  ...         71         70          71        66
# 54         66400000  ...         80         83          80        81
# 66         51000000  ...         78         82          78        80
# 71         61600000  ...         80         82          80        79
# 77         26800000  ...         35         40          35        34
# 92         65599999  ...         69         69          69        67
# 95         28900000  ...         78         79          78        79
# 118        18500000  ...         75         74          75        74
# 147         6700000  ...         59         57          59        57
# 149         5400000  ...         57         54          57        55
# 153          148000  ...         26         27          26        26
# 167         2900000  ...         60         54          60        61
# 168         1500000  ...         47         43          47        44
# 170         1600000  ...         57         58          57        57
# 171         1200000  ...         58         53          58        58
#
#     CB Rating  RB Rating  GK Rating  Nationality  Gap_Potential  Real_OScore
# 2          72         78         24      Belgium              0         91.0
# 5          38         39         90       Brazil              2         90.0
# 6          90         83         21     Portugal              3         89.5
# 7          65         64         22       Norway              6         91.0
# 9          67         75         21     Portugal              0         88.0
# 10         82         87         22     Portugal              0         88.0
# 14         85         82         21        Spain              2         88.0
# 18         52         62         21      Algeria              0         86.0
# 19         87         81         21        Spain              1         86.5
# 24         75         78         22      Germany              0         85.0
# 25         84         85         22      England              0         85.0
# 30         62         72         22      England              7         88.5
# 35         57         66         21      England              0         84.0
# 54         84         81         20      England              1         83.5
# 66         82         80         19  Switzerland              1         81.5
# 71         81         79         20      England              4         83.0
# 77         35         34         80      Germany              0         80.0
# 92         64         67         19    Argentina              8         82.0
# 95         80         79         21  Netherlands              2         79.0
# 118        69         74         19        Spain              9         78.5
# 147        52         57         17      England             18         76.0
# 149        50         55         18      England             16         74.0
# 153        29         26         65      England              0         65.0
# 167        59         61         19      England             21         71.5
# 168        38         44         16      England             14         67.0
# 170        55         57         16      England             20         68.0
# 171        56         58         16      England             18         67.0
#
# [27 rows x 35 columns]

# %%
#Focusing our data on the columns needed to determine who we would like to transfer:

Fifa_MC2.columns
# Out:
# Index(['Known As', 'Overall', 'Mean Overall', 'Potential', 'Positions Played',
#        'Club Name', 'Value(in Euro)', 'Best Position', 'Wage(in Euro)',
#        'Release Clause', 'Club Position', 'Contract Until', 'Joined On',
#        'On Loan', 'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
#        'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
#        'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
#        'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
#        'Gap_Potential', 'Real_OScore'],
#       dtype='object')

# %%
Fifa_MC2 = Fifa_MC2[['Known As', 'Overall','Potential', 'Real_OScore','Mean Overall', 'Club Name',
       'Value(in Euro)','Positions Played', 'Club Position']]

Fifa_MC2
# Out:
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position
# 2    Manchester City       107500000           CM,CAM            CM
# 5    Manchester City        88000000               GK            GK
# 6    Manchester City       107500000               CB            CB
# 7    Manchester City       148000000               ST            ST
# 9    Manchester City        97500000           CAM,CM            RW
# 10   Manchester City        82500000            LB,RB            LB
# 14   Manchester City        88500000              CDM           CDM
# 18   Manchester City        56500000            RW,RM           SUB
# 19   Manchester City        64500000               CB            CB
# 24   Manchester City        44000000           CM,CDM            CM
# 25   Manchester City        37500000               RB            RB
# 30   Manchester City       109500000        LW,CF,CAM            LW
# 35   Manchester City        46000000        LW,LM,CAM           SUB
# 54   Manchester City        34500000               CB           SUB
# 66   Manchester City        26500000               CB           SUB
# 71   Manchester City        32000000           CDM,CM           SUB
# 77   Manchester City        14500000               GK           SUB
# 92   Manchester City        32000000         ST,RW,LW           SUB
# 95   Manchester City        15000000            CB,LB           SUB
# 118  Manchester City         9000000         LB,RM,LM           SUB
# 147  Manchester City         2700000        RW,CAM,CF           SUB
# 149  Manchester City         2200000            LW,RW           RES
# 153  Manchester City           80000               GK           SUB
# 167  Manchester City         1000000               RB           SUB
# 168  Manchester City          600000               RW           RES
# 170  Manchester City          575000               CM           RES
# 171  Manchester City          500000               LB           RES

# %%
#Creating a new column with a boolean analysis to highlight players with a Real_OScore below the mean of the Champions leage top 10 teams.

Fifa_MC2["A1_Transfer?"] = np.where(Fifa_MC2["Real_OScore"] < Fifa_MC2["Mean Overall"], True, False)
Fifa_MC2
# Out:
# <ipython-input-174-85bf40673013>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_MC2["A1_Transfer?"] = np.where(Fifa_MC2["Real_OScore"] < Fifa_MC2["Mean Overall"], True, False)
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position  \
# 2    Manchester City       107500000           CM,CAM            CM
# 5    Manchester City        88000000               GK            GK
# 6    Manchester City       107500000               CB            CB
# 7    Manchester City       148000000               ST            ST
# 9    Manchester City        97500000           CAM,CM            RW
# 10   Manchester City        82500000            LB,RB            LB
# 14   Manchester City        88500000              CDM           CDM
# 18   Manchester City        56500000            RW,RM           SUB
# 19   Manchester City        64500000               CB            CB
# 24   Manchester City        44000000           CM,CDM            CM
# 25   Manchester City        37500000               RB            RB
# 30   Manchester City       109500000        LW,CF,CAM            LW
# 35   Manchester City        46000000        LW,LM,CAM           SUB
# 54   Manchester City        34500000               CB           SUB
# 66   Manchester City        26500000               CB           SUB
# 71   Manchester City        32000000           CDM,CM           SUB
# 77   Manchester City        14500000               GK           SUB
# 92   Manchester City        32000000         ST,RW,LW           SUB
# 95   Manchester City        15000000            CB,LB           SUB
# 118  Manchester City         9000000         LB,RM,LM           SUB
# 147  Manchester City         2700000        RW,CAM,CF           SUB
# 149  Manchester City         2200000            LW,RW           RES
# 153  Manchester City           80000               GK           SUB
# 167  Manchester City         1000000               RB           SUB
# 168  Manchester City          600000               RW           RES
# 170  Manchester City          575000               CM           RES
# 171  Manchester City          500000               LB           RES
#
#      A1_Transfer?
# 2           False
# 5           False
# 6           False
# 7           False
# 9           False
# 10          False
# 14          False
# 18          False
# 19          False
# 24          False
# 25          False
# 30          False
# 35          False
# 54          False
# 66          False
# 71          False
# 77          False
# 92          False
# 95          False
# 118         False
# 147         False
# 149         False
# 153          True
# 167          True
# 168          True
# 170          True
# 171          True

# %%
"""
According to this first analysis, the players to transfer are the following:

S. Carson, R. Lewis, B. Knight, A. Robertson, J. Wilson-Esbrand

"""
# Out:
# '\nAccording to this first analysis, the players to transfer are the following: \n\nS. Carson, R. Lewis, B. Knight, A. Robertson, J. Wilson-Esbrand\n\n'

# %% [markdown]
# ***ANALYSIS 2 - Determining players to transfer according to their age and release date. ***

# %%
Fifa_Cle.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'Club Name', 'Wage(in Euro)', 'Release Clause',
#        'Club Position', 'Contract Until', 'Joined On', 'On Loan',
#        'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
#        'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
#        'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
#        'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
#        'Gap_Potential'],
#       dtype='object')

# %%
Fifa_A2 = Fifa_MC2

Fifa_A2["Age"] = Fifa["Age"]
Fifa_A2["Wage (in euro)"] = Fifa["Wage(in Euro)"]
Fifa_A2["Release Clause"] = Fifa["Release Clause"]
Fifa_A2["Contract Until"] = Fifa["Contract Until"]

Fifa_A2
# Out:
# <ipython-input-177-5c777df7175f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Age"] = Fifa["Age"]
# <ipython-input-177-5c777df7175f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Wage (in euro)"] = Fifa["Wage(in Euro)"]
# <ipython-input-177-5c777df7175f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Release Clause"] = Fifa["Release Clause"]
# <ipython-input-177-5c777df7175f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Contract Until"] = Fifa["Contract Until"]
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position  \
# 2    Manchester City       107500000           CM,CAM            CM
# 5    Manchester City        88000000               GK            GK
# 6    Manchester City       107500000               CB            CB
# 7    Manchester City       148000000               ST            ST
# 9    Manchester City        97500000           CAM,CM            RW
# 10   Manchester City        82500000            LB,RB            LB
# 14   Manchester City        88500000              CDM           CDM
# 18   Manchester City        56500000            RW,RM           SUB
# 19   Manchester City        64500000               CB            CB
# 24   Manchester City        44000000           CM,CDM            CM
# 25   Manchester City        37500000               RB            RB
# 30   Manchester City       109500000        LW,CF,CAM            LW
# 35   Manchester City        46000000        LW,LM,CAM           SUB
# 54   Manchester City        34500000               CB           SUB
# 66   Manchester City        26500000               CB           SUB
# 71   Manchester City        32000000           CDM,CM           SUB
# 77   Manchester City        14500000               GK           SUB
# 92   Manchester City        32000000         ST,RW,LW           SUB
# 95   Manchester City        15000000            CB,LB           SUB
# 118  Manchester City         9000000         LB,RM,LM           SUB
# 147  Manchester City         2700000        RW,CAM,CF           SUB
# 149  Manchester City         2200000            LW,RW           RES
# 153  Manchester City           80000               GK           SUB
# 167  Manchester City         1000000               RB           SUB
# 168  Manchester City          600000               RW           RES
# 170  Manchester City          575000               CM           RES
# 171  Manchester City          500000               LB           RES
#
#      A1_Transfer?  Age  Wage (in euro)  Release Clause Contract Until
# 2           False   33          420000       172200000           2025
# 5           False   30          270000       213700000           2023
# 6           False   30          250000       191300000           2026
# 7           False   36           72000        22300000           2024
# 9           False   30          230000       181300000           2025
# 10          False   28          240000       200500000           2024
# 14          False   29          100000       181700000           2023
# 18          False   29          190000       152100000           2027
# 19          False   31          220000       133199999           2023
# 24          False   28          250000       152600000           2027
# 25          False   28          170000       177100000           2024
# 30          False   29          250000       156200000           2026
# 35          False   31          150000        79800000           2023
# 54          False   33           64000        88200000           2024
# 66          False   28           48000       114500000           2026
# 71          False   33          190000        57400000           2024
# 77          False   30           46000        97700000           2024
# 92          False   36           75000        13900000           2023
# 95          False   35           86000        34200000           2023
# 118         False   34          160000        34000000           2023
# 147         False   25           57000       115300000           2024
# 149         False   25          105000        93800000           2024
# 153          True   29          105000        58000000           2026
# 167          True   26          110000        80000000           2025
# 168          True   24           95000        97800000           2027
# 170          True   25          100000       102000000           2027
# 171          True   24           40000        78100000           2026

# %%
Fifa_CU = Fifa_A2[Fifa_A2['Contract Until'].isin(["2023","2024"])]
Fifa_CU
# Out:
#          Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 5         Ederson       89         91         90.0     76.473684
# 7      E. Haaland       88         94         91.0     79.454545
# 10   João Cancelo       88         88         88.0     88.000000
# 14          Rodri       87         89         88.0     79.000000
# 19     A. Laporte       86         87         86.5     80.083333
# 25      K. Walker       85         85         85.0     76.000000
# 35    J. Grealish       84         84         84.0     84.000000
# 54      J. Stones       83         84         83.5     80.083333
# 71    K. Phillips       81         85         83.0     79.777778
# 77      S. Ortega       80         80         80.0     76.473684
# 92     J. Álvarez       78         86         82.0     78.000000
# 95         N. Aké       78         80         79.0     72.500000
# 118  Sergio Gómez       74         83         78.5     74.000000
# 147     C. Palmer       67         85         76.0     67.000000
# 149     M. Rogers       66         82         74.0     71.333333
#
#            Club Name  Value(in Euro) Positions Played Club Position  \
# 5    Manchester City        88000000               GK            GK
# 7    Manchester City       148000000               ST            ST
# 10   Manchester City        82500000            LB,RB            LB
# 14   Manchester City        88500000              CDM           CDM
# 19   Manchester City        64500000               CB            CB
# 25   Manchester City        37500000               RB            RB
# 35   Manchester City        46000000        LW,LM,CAM           SUB
# 54   Manchester City        34500000               CB           SUB
# 71   Manchester City        32000000           CDM,CM           SUB
# 77   Manchester City        14500000               GK           SUB
# 92   Manchester City        32000000         ST,RW,LW           SUB
# 95   Manchester City        15000000            CB,LB           SUB
# 118  Manchester City         9000000         LB,RM,LM           SUB
# 147  Manchester City         2700000        RW,CAM,CF           SUB
# 149  Manchester City         2200000            LW,RW           RES
#
#      A1_Transfer?  Age  Wage (in euro)  Release Clause Contract Until
# 5           False   30          270000       213700000           2023
# 7           False   36           72000        22300000           2024
# 10          False   28          240000       200500000           2024
# 14          False   29          100000       181700000           2023
# 19          False   31          220000       133199999           2023
# 25          False   28          170000       177100000           2024
# 35          False   31          150000        79800000           2023
# 54          False   33           64000        88200000           2024
# 71          False   33          190000        57400000           2024
# 77          False   30           46000        97700000           2024
# 92          False   36           75000        13900000           2023
# 95          False   35           86000        34200000           2023
# 118         False   34          160000        34000000           2023
# 147         False   25           57000       115300000           2024
# 149         False   25          105000        93800000           2024

# %%
# Define the criteria for the data that we want to highlight
age_threshold = 25
oscore_threshold = 3.5  #determine the difference from the mean that we will target.

highlight_mask = (
    (Fifa_CU['Age'] > age_threshold) &
    (abs(Fifa_CU['Real_OScore'] - Fifa_CU['Mean Overall']) <= oscore_threshold)
)

# Create a new column "A2_Transfer?" with True for the players we will transfer, and False otherwise.
Fifa_CU['A2_Transfer?'] = highlight_mask


Fifa_CU
# Out:
# <ipython-input-180-b57cac631d32>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_CU['A2_Transfer?'] = highlight_mask
#          Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 5         Ederson       89         91         90.0     76.473684
# 7      E. Haaland       88         94         91.0     79.454545
# 10   João Cancelo       88         88         88.0     88.000000
# 14          Rodri       87         89         88.0     79.000000
# 19     A. Laporte       86         87         86.5     80.083333
# 25      K. Walker       85         85         85.0     76.000000
# 35    J. Grealish       84         84         84.0     84.000000
# 54      J. Stones       83         84         83.5     80.083333
# 71    K. Phillips       81         85         83.0     79.777778
# 77      S. Ortega       80         80         80.0     76.473684
# 92     J. Álvarez       78         86         82.0     78.000000
# 95         N. Aké       78         80         79.0     72.500000
# 118  Sergio Gómez       74         83         78.5     74.000000
# 147     C. Palmer       67         85         76.0     67.000000
# 149     M. Rogers       66         82         74.0     71.333333
#
#            Club Name  Value(in Euro) Positions Played Club Position  \
# 5    Manchester City        88000000               GK            GK
# 7    Manchester City       148000000               ST            ST
# 10   Manchester City        82500000            LB,RB            LB
# 14   Manchester City        88500000              CDM           CDM
# 19   Manchester City        64500000               CB            CB
# 25   Manchester City        37500000               RB            RB
# 35   Manchester City        46000000        LW,LM,CAM           SUB
# 54   Manchester City        34500000               CB           SUB
# 71   Manchester City        32000000           CDM,CM           SUB
# 77   Manchester City        14500000               GK           SUB
# 92   Manchester City        32000000         ST,RW,LW           SUB
# 95   Manchester City        15000000            CB,LB           SUB
# 118  Manchester City         9000000         LB,RM,LM           SUB
# 147  Manchester City         2700000        RW,CAM,CF           SUB
# 149  Manchester City         2200000            LW,RW           RES
#
#      A1_Transfer?  Age  Wage (in euro)  Release Clause Contract Until  \
# 5           False   30          270000       213700000           2023
# 7           False   36           72000        22300000           2024
# 10          False   28          240000       200500000           2024
# 14          False   29          100000       181700000           2023
# 19          False   31          220000       133199999           2023
# 25          False   28          170000       177100000           2024
# 35          False   31          150000        79800000           2023
# 54          False   33           64000        88200000           2024
# 71          False   33          190000        57400000           2024
# 77          False   30           46000        97700000           2024
# 92          False   36           75000        13900000           2023
# 95          False   35           86000        34200000           2023
# 118         False   34          160000        34000000           2023
# 147         False   25           57000       115300000           2024
# 149         False   25          105000        93800000           2024
#
#      A2_Transfer?
# 5           False
# 7           False
# 10           True
# 14          False
# 19          False
# 25          False
# 35           True
# 54           True
# 71           True
# 77          False
# 92          False
# 95          False
# 118         False
# 147         False
# 149         False

# %%
"""

After this second analysis, we finaly decided to transfer those players :
João Cancelo, J. Grealish,	J. Stones, K. Phillips


For the following reasons:

- Their contracts are ending in 2023 or 2024 so we can avoid the release clause.
- They are players older than 25, and we know that players have more potential when below 25 years.
- Their Real_OScore are the closest to the Mean Overall of our Champions Leagues Top 10 teams which takes into account their Overall and potential.

"""
